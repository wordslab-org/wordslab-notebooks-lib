# %% [raw]
# ---
# description: Python library to help with AI usage in  wordslab-notebokks
# output-file: index.html
# title: wordslab-notebooks-lib
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Introduction
#
# [wordslab-notebooks-lib](https://github.com/wordslab-org/wordslab-notebooks-lib) is a companion library for [wordslab-notebooks](https://github.com/wordslab-org/wordslab-notebooks?tab=readme-ov-file#wordslab-notebooks).
#
# **wordslab-notebooks** is a one click install of all the tools you need to learn, explore and build AI applications on your own machine.
# - Recent and compatible versions of the best open source tools
# - Optimized work environment to save disk space and memory
# - Options to leverage your own machines at home or to rent more powerful machines in the cloud
# - Documentation to guide you in your AI learning and exploration journey
#
# 3 main applications
# - A rich chat interface (text, images, voice) : Open WebUI
# - A notebooks platform (text & code) : JupyterJab + Jupyter AI extension
# - A development environment (code) : Visual Studio Code + Continue.dev extension + Aider terminal agent
#
# Fully integrated AI environment with
# - A visual dashboard to help you navigate all applications and manage your machine resources
# - Optimized inference engines to run AI models : Ollama + vLLM
#
# **wordslab-notebooks-lib** is meant to be used in Jupyterlab notebooks or python programs running inside the wordslab-notebooks environment.
#
# It provides many helper functions to easily access and use all the applications and resources of the environment.

# %% [markdown]
# ## Getting started

# %% [markdown]
# ### Installation

# %% [markdown]
# ```sh
# $ pip install wordslab_notebooks_lib
# ```
#
# [repo]: https://github.com/wordslab-org/wordslab-notebooks-lib
# [docs]: https://wordslab-org.github.io/wordslab-notebooks-lib/
# [pypi]: https://pypi.org/project/wordslab-notebooks-lib/

# %% [markdown]
# ### Documentation

# %% [markdown]
# Please read the documentation to discover all the features of the library:
#
# https://wordslab-org.github.io/wordslab-notebooks-lib/

# %% [markdown]
# ### First steps

# %% [markdown]
# The [`WordslabNotebooks`](https://wordslab-org.github.io/wordslab-notebooks-lib/core.html#wordslabnotebooks) class is the main entrypoint to discover all wordslab-notebooks resources.

# %%
from wordslab_notebooks_lib.core import *

wlnb = WordslabNotebooks()

# %% [markdown]
# wordslab-notebooks version

# %%
wlnb.version
# Out:
# '2025-11'

# %% [markdown]
# wordslab-notebooks external urls

# %%
wlnb.url_dashboard
# Out:
# 'http://192.168.1.197:8888'

# %%
wlnb.url_userapp1
# Out:
# 'https://192.168.1.197:8883'

# %% [markdown]
# wordslab-notebooks internal ports

# %%
wlnb.port_ollama
# Out:
# 11434

# %%
wlnb.port_userapp1
# Out:
# '8883'

# %% [markdown]
# wordslab-notebooks install directories

# %%
wlnb.dir_scripts
# Out:
# '/home/wordslab-notebooks-2025-11'

# %%
wlnb.dir_workspace
# Out:
# '/home/workspace'

# %% [markdown]
# wordslab-notebooks applications data directories

# %%
wlnb.dir_openwebui_data
# Out:
# '/home/workspace/.openwebui'

# %%
wlnb.dir_jupyterlab_data
# Out:
# '/home/workspace/.jupyter'

# %% [markdown]
# wordslab-notebooks models directories

# %%
wlnb.dir_models_ollama
# Out:
# '/home/models/ollama'

# %%
wlnb.dir_models_vllm
# Out:
# '/home/models/huggingface'

# %% [markdown]
# wordslab-notebooks default models

# %%
wlnb.default_model_chat
# Out:
# 'gemma3:27b'

# %%
wlnb.default_model_code
# Out:
# 'qwen3:30b'
