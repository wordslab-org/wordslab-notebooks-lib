# %% [raw]
# ---
# description: WordslabNotebooks class enables easy access to all of the wordslab-notebooks
#   directories, applications, workspace projects and models.
# output-file: core.html
# title: wordslab-notebooks-lib.core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## WordslabNotebooks class

# %%
#| echo: false
#| output: asis
show_doc(WordslabNotebooks)
# Out:
# ---
#
# [source](https://github.com/wordslab-org/wordslab-notebooks-lib/blob/main/wordslab_notebooks_lib/core.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### WordslabNotebooks
#
# >      WordslabNotebooks ()
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %% [markdown]
# The WordslabNotebooks class is the entry point to explore the worslab-notebooks environment.

# %%
wlnb = WordslabNotebooks()

# %% [markdown]
# ### wordslab-notebooks version and platform

# %%
wlnb.version
# Out:
# '2025-11'

# %%
wlnb.platform
# Out:
# 'WindowsSubsystemForLinux'

# %% [markdown]
# ### wordslab-notebooks external urls

# %%
wlnb.url_dashboard
# Out:
# 'http://192.168.1.197:8888'

# %%
wlnb.url_openwebui
# Out:
# 'https://192.168.1.197:8882'

# %%
wlnb.url_jupyterlab
# Out:
# 'https://192.168.1.197:8880'

# %%
wlnb.url_vscode
# Out:
# 'https://192.168.1.197:8881'

# %%
wlnb.url_userapp1
# Out:
# 'https://192.168.1.197:8883'

# %%
wlnb.url_userapp2
# Out:
# 'https://192.168.1.197:8884'

# %%
wlnb.url_userapp3
# Out:
# 'https://192.168.1.197:8885'

# %%
wlnb.url_userapp4
# Out:
# 'https://192.168.1.197:8886'

# %%
wlnb.url_userapp5
# Out:
# 'https://192.168.1.197:8887'

# %% [markdown]
# ### wordslab-notebooks internal ports

# %%
wlnb.port_ollama
# Out:
# 11434

# %%
wlnb.port_vllm
# Out:
# 8000

# %%
wlnb.port_docling
# Out:
# 5001

# %%
wlnb.port_userapp1
# Out:
# '8883'

# %%
wlnb.port_userapp2
# Out:
# '8884'

# %%
wlnb.port_userapp3
# Out:
# '8885'

# %%
wlnb.port_userapp4
# Out:
# '8886'

# %%
wlnb.port_userapp5
# Out:
# '8887'

# %% [markdown]
# ### wordslab-notebooks install directories

# %%
wlnb.dir_home
# Out:
# '/home'

# %%
wlnb.dir_scripts
# Out:
# '/home/wordslab-notebooks-2025-11'

# %%
wlnb.dir_python
# Out:
# '/home/python'

# %%
wlnb.dir_workspace
# Out:
# '/home/workspace'

# %%
wlnb.dir_models
# Out:
# '/home/models'

# %% [markdown]
# ### wordslab-notebooks applications install directories

# %%
wlnb.dir_openwebui
# Out:
# '/home/open-webui'

# %%
wlnb.dir_jupyterlab
# Out:
# '/home/jupyterlab'

# %%
wlnb.dir_vscode
# Out:
# '/home/code-server'

# %%
wlnb.dir_ollama
# Out:
# '/home/ollama'

# %%
wlnb.dir_docling
# Out:
# '/home/docling'

# %% [markdown]
# ### wordslab-notebooks applications data directories

# %%
wlnb.dir_openwebui_data
# Out:
# '/home/workspace/.openwebui'

# %%
wlnb.dir_jupyterlab_data
# Out:
# '/home/workspace/.jupyter'

# %%
wlnb.dir_vscode_data
# Out:
# '/home/workspace/.codeserver'

# %%
wlnb.dir_docling_data
# Out:
# '/home/workspace/.docling'

# %% [markdown]
# ### wordslab-notebooks models directories

# %%
wlnb.dir_models_ollama
# Out:
# '/home/models/ollama'

# %%
wlnb.dir_models_vllm
# Out:
# '/home/models/huggingface'

# %%
wlnb.dir_models_hugginface
# Out:
# '/home/models/huggingface'

# %%
wlnb.dir_models_fastai
# Out:
# '/home/models/fastai'

# %%
wlnb.dir_models_pytorch
# Out:
# '/home/models/torch'

# %%
wlnb.dir_models_keras
# Out:
# '/home/models/keras'

# %%
wlnb.dir_models_tensorflow
# Out:
# '/home/models/tfhub_modules'

# %%
wlnb.dir_models_docling
# Out:
# '/home/models/docling'

# %% [markdown]
# ### wordslab-notebooks default models

# %%
wlnb.default_model_chat
# Out:
# 'gemma3:27b'

# %%
wlnb.default_model_embedding
# Out:
# 'embeddinggemma:300m'

# %%
wlnb.default_model_code
# Out:
# 'qwen3:30b'

# %%
wlnb.default_model_autocomplete
# Out:
# 'qwen2.5-coder:1.5b-base'
